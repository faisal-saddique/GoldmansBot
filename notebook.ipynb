# %%
from langchain.document_loaders.recursive_url_loader import RecursiveUrlLoader
from bs4 import BeautifulSoup as Soup

def scrape_website_recursively(url):
    loader = RecursiveUrlLoader(url=url, max_depth=2, extractor=lambda x: Soup(x, "html.parser").text)
    docs = loader.load()
    return docs

# %%
docs = scrape_website_recursively("https://www.twilio.com/docs/sms")

# %%
docs
# Out:
# [Document(page_content='\ufeff\n\n\n\n\n\n\n\n\n\n\n\n      Send SMS with Twilio Programmable Messaging | Twilio\n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to main content\n\n\n Twilio Docs\n\n\n\nMessaging\n\n\nVoice\n\n\nServerless\n\n\nVideo\n\n\nStudio\n\n\nAll docs...\n\n\n\n\n\n\nEnglish\n\n\n\n\nDeutsch\n\n\nEnglish\n\n\n\n\n\n\n\nSDKs\n\n\nHelp\n\n\n\n\n\nLog in\n\n\nSign up\n\n\n\n\n\n\n\n\n\n\n\n\nMessaging\nVoice\nServerless\nVideo\nStudio\nAll docs...\nSDKs\nHelp\nLog in\nSign up\n\n\nChoose Your Language\nDeutsch\nEnglish\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n        Programmable Messaging\n      \n\n\n\nTwilio\n\n\n\n\n\nMenu\n\n\n\n\n\n\n\n\n\nGetting Started\n\n\n\n          How to Work with your Free Twilio Trial Account\n      \n\n\n\n          Programmable Messaging Quickstarts\n      \n\n\n\n          The Incoming Message Webhook\n      \n\n\n\n\n\nAPI Reference\n\n\n\n          API Overview\n      \n\n\n\n          Message Resource\n    
# ...
